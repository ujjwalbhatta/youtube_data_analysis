# %%
api_key = 'AIzaSyCWGKa8684OAdWTVot1aaQ1Ld_P0leJ-d8'

# %%
from apiclient.discovery import build

# %%
youtube = build('youtube','v3',developerKey=api_key)

# %%
def get_channel_videos(channel_id):
    res = youtube.channels().list(id=channel_id,
                             part='contentDetails').execute()
    playlist_id = res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    videos = []
    next_page_token = None
    
    while 1:
        res = youtube.playlistItems().list(playlistId=playlist_id,
                                  part='snippet',
                                  maxResults= 50,
                                  pageToken= next_page_token).execute()
            
        videos += res['items']
        next_page_token = res.get('nextPageToken')
            
        if next_page_token is None:
            break
            
    return videos

# %%
videos = get_channel_videos('UCkUq-s6z57uJFUFBvZIVTyg')

# %%
len(videos)
# Out:
# 250

# %%
videos[0]
# Out:
# {'kind': 'youtube#playlistItem',
#  'etag': 'pI4ELCEKVLK-L1w1HD0Zy1xPB0o',
#  'id': 'VVVrVXEtczZ6NTd1SkZVRkJ2WklWVHlnLldndzVlcnM1akE0',
#  'snippet': {'publishedAt': '2020-05-10T12:30:13Z',
#   'channelId': 'UCkUq-s6z57uJFUFBvZIVTyg',
#   'title': 'Introduction to PyPy',
#   'description': 'A brief introduction to PyPy.  PyPy is an alternative implementation of the Python programming language to CPython (which is the standard implementation). PyPy often runs faster than CPython because PyPy is a just-in-time compiler while CPython is an interpreter.\n\nReferences: https://gist.github.com/nikhilkumarsingh/c4a2ab60759fd125ee03651be46e55ae\n\n#pypy #python #interpreter',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Wgw5ers5jA4/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/Wgw5ers5jA4/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/Wgw5ers5jA4/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/Wgw5ers5jA4/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/Wgw5ers5jA4/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'channelTitle': 'Indian Pythonista',
#   'playlistId': 'UUkUq-s6z57uJFUFBvZIVTyg',
#   'position': 0,
#   'resourceId': {'kind': 'youtube#video', 'videoId': 'Wgw5ers5jA4'}}}

# %%
res= youtube.videos().list(id=videos[0]['snippet']['resourceId']['videoId'],
                          part='statistics').execute()

# %%
res
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'FX3rhLIvN5gnIVGoEWAbW6Yb9HE',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'zLXGtGsZjK60lLgPi0J_n-svzKc',
#    'id': 'Wgw5ers5jA4',
#    'statistics': {'viewCount': '496',
#     'likeCount': '27',
#     'dislikeCount': '2',
#     'favoriteCount': '0',
#     'commentCount': '6'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %%
def get_video_stats(video_ids):
    stats = []
    for i in range(0,len(video_ids),50):
        res = youtube.videos().list(id=','.join(video_ids[i:i+50]),
                                   part='statistics').execute()
        stats += res['items']
    return stats

# %%
video_ids = list(map(lambda x:x['snippet']['resourceId']['videoId'],videos))

# %%
video_ids
# Out:
# ['Wgw5ers5jA4',
#  'my2vBYZ1RFw',
#  'Jztj_yuFTlk',
#  'U4dSWJFIQ0A',
#  'WTofttoD2xg',
#  'oYFzQB9zj5I',
#  '8O8VNuYyplU',
#  'vHMvobBbQJc',
#  'I93i7KGggcg',
#  'BiV-kdQbEo0',
#  'dT9ymsYVVu8',
#  'FbfV9N_va7Y',
#  'sTr30oviyHc',
#  'bw1gfnLSmd0',
#  'xZXsR7soexU',
#  'ckNUeTNBwT4',
#  'vDxrmKOJMJ8',
#  'DiXRBYi1KDI',
#  '8NW2IzfoY2Y',
#  'PHX1kraTTrE',
#  'uJC8A_7VZOA',
#  '95y1N6MFCNs',
#  'Rw4hrXQi1CI',
#  'xeeUgn08F94',
#  'hCJpNPsS54Y',
#  'gULdbWqbTIE',
#  'hMIoc2wxTug',
#  'Vc5kGYty18k',
#  'Q2CNZGEH59Q',
#  'j1mh0or2CX8',
#  'kKl7scEW90c',
#  '9n4uJG_Qg44',
#  'sH5XSdXksAg',
#  '7tYEsT2dzlo',
#  'VQnmcBnguPY',
#  'IBhdLRheKyM',
#  'Ks9HWZWMsw4',
#  'BvbqI6eDh0c',
#  'zwMsmBsC1GM',
#  'BK7YvpTT4Sw',
#  'bytnxnZFLeg',
#  'HiillVo1gJY',
#  '4ho21Wppf30',
#  'EeUdel2AJ5g',
#  'BKK5NMDC0fk',
#  'k7_pSwjieiQ',
#  'ELcNjenTpCo',
#  '6zge0N962aw',
#  'twuhocLtGCg',
#  '_uPsxnIg0uU',
#  'DSSvVd1uo8o',
#  'xoQ7TdB-9NI',
#  'r4Z7kmsauTA',
#  'tD-dZjDWTZI',
#  'DQNEj26i6og',
#  '1kwXDCCcvvE',
#  '2_IogBzts-M',
#  'MUXEuOJAm2Q',
#  'fB8GLixWRrY',
#  'vFiBKa4VbtU',
#  'a_LRNBFVCq8',
#  'WO2s7jUF5mk',
#  '7CpRn3d1z_g',
#  'Mf-4Zcz5VKw',
#  'LIcAmQec5K8',
#  'xp1vX15inBg',
#  'Nr-gYadj5dw',
#  'cUx9qUkYJgk',
#  'fujPIABgUD0',
#  'FXhbksjm3Ec',
#  '6WTFF-mKZX8',
#  'NEOSf7VKTTc',
#  '8wRfskrpTIk',
#  'aAbQTODpats',
#  'PV4TdArivCk',
#  '2wME30BZuFY',
#  'dl9K13PCdJ0',
#  'j0GRmMh74yw',
#  'ivK4ImvhUfo',
#  'AzKV9NbtNJ0',
#  'jhqODb3Rpxo',
#  'Qf1gIpmHK6Y',
#  'wMypio8N95k',
#  'ZVfLGUpKuwQ',
#  '65fBlCJ_vVg',
#  'MoeXYCV830E',
#  '9iRcu2VKsIg',
#  '6pipGjJZR5c',
#  'vkqwsS3L13o',
#  'JRXhCmmLbeY',
#  'HfAX9p8dNCY',
#  'qSwdeqeHmRY',
#  'DEqIiH_bkFc',
#  'L5TBwa9sD78',
#  '3eAMvnIxQd0',
#  '3YrnVx8WLVQ',
#  'b8IpJT05uBo',
#  'WyzRRyKeea4',
#  'Wa0e6R3sZWc',
#  'j5EvjSLeRqg',
#  'cymDVY_pkYo',
#  '6f6dTBQXa8Y',
#  'PeSXwg72_KE',
#  'RgfOjrjhCMY',
#  'sPJ28bdBH-w',
#  'KTaLs494xgo',
#  'yAdGRuEarVw',
#  '_JdUzQFFLn0',
#  'ZPM8TCz5cd8',
#  '-zJ1x2QHTKE',
#  'gZEwmdgEMqE',
#  '5ff4_YK83fQ',
#  'KptmT3gQn3g',
#  'WIz9KRii2Lk',
#  'v5u5zSYKhFs',
#  'oU86kvDbSNw',
#  'PQXfVo0jIo4',
#  'WSLtyzjsIY4',
#  '-3PUuhLekbk',
#  'Ju4xkvFm07o',
#  'Hh47pBRkhns',
#  'tmMqdrEzVRI',
#  'c6uoxhaenHg',
#  'y85G7GLYhYA',
#  'lTdX45rle7A',
#  'G7-Y0rhPPsw',
#  'ya8FfxkKN4g',
#  'f77rKzqBzEA',
#  '2CvzoNPSOHg',
#  'Kj8v9mYS0Ik',
#  'zyo1PLw4hrE',
#  'RH_lRGb-qds',
#  'Yr_PTfYElw8',
#  'DkO3g0ITyuc',
#  'f4Q-L4vGdh8',
#  '1psWpWml_VE',
#  'aKIFaFU2X00',
#  '-QMg39gK624',
#  'b_jOJNUD350',
#  'H4fQUHVvbX8',
#  'IK5UUrPglTM',
#  'wq570TYG-eg',
#  'uBHOb55-fBo',
#  'sCneLptDZ4I',
#  'oS5PahnKf_E',
#  'Y4d7_0Tt0U0',
#  '4W06lWibPyc',
#  'DTco1nTTlzE',
#  'oOJr7XTj-Zw',
#  'rlKl2q3Vy90',
#  'n3uSyqoBgQI',
#  'K4aZuBeG8fU',
#  'gITfjV_Tdns',
#  'yDWCfEbgyBo',
#  'GIywmJbGH-8',
#  'EsUTO4Xzehg',
#  'IKRFY5uFoOQ',
#  'HRqxIizljgo',
#  'fmf_y8zpOgA',
#  'T4oLluJaCIE',
#  'QSwXIIkxPcQ',
#  'aFw8znSCqXM',
#  'luMnpyKR6C0',
#  'CZzFbWAljp8',
#  'NcaMLIUpjbY',
#  '_sS5s0Nd-qc',
#  's6C3kYCNmLc',
#  'B55roI7rE_Y',
#  'IIzOQhf5AKo',
#  '-Zy18QEFm6s',
#  'axVcw9WWZz4',
#  'yGYMZIQQJTY',
#  'z4aaSVh5r_8',
#  '0y0V0ObEhoo',
#  'f3EVLwESJss',
#  'GWdrL8dt1xQ',
#  'CoZbtZJg13A',
#  '2Mk6yPMFdFA',
#  'wd3ZTyjknOo',
#  'qbZOytnC8eI',
#  'GO460-dGTdU',
#  'l3FfnXFcprU',
#  'vbs8_FlU63w',
#  'OggZfhyhDos',
#  '6i5bHQZ-c5U',
#  '-mJXEzSD1Ic',
#  'op3tFHLbMas',
#  'QP7pwaRA-LA',
#  'oGbX05orp2A',
#  'zTHtUm4AtcA',
#  'SpDI6-FvtJY',
#  'J-o99pzbBJk',
#  '9G5vsZemFVM',
#  'clT8wH_Us5g',
#  'wN43Iypd_MA',
#  '95p3cVkqYHQ',
#  'BX9BTQf9-Fc',
#  '8GRUwftKAps',
#  'B7aULKpPFWg',
#  'hk3ubc1-ZGg',
#  'ym4V6yZh4yU',
#  'oD4IvH-Talo',
#  '2JGU9S2gCMg',
#  'j5KwP4ifHWs',
#  'hSuHnuNC8L4',
#  '5gR6ObKkIeY',
#  '_3n0AiYP5DU',
#  '2tWDA7SclXk',
#  'ialnWPvouZ4',
#  'cVzOEli3zaA',
#  'pHliYIPnxZU',
#  'TQHDgyQ60B0',
#  'YJ1loqmAKpk',
#  'JtKOP-ThcbU',
#  'oritw8qAR1U',
#  'dTRXjoVq_RE',
#  'FInLfuYzJhA',
#  'ek0FYB9zXJw',
#  '3aHJmbosJYs',
#  'cefqrkkWOnM',
#  'RzdBslEwsig',
#  'SlrLZ1no08A',
#  'Xhw2l-hzoKk',
#  'kUxEInTQUhA',
#  'ruAownOJJKA',
#  'RGSoVGtuHuA',
#  'jWh0FaRRZC4',
#  'LQ2hbNFOs_Q',
#  'XgohEG9fqNQ',
#  'e29Aj6tJ_5k',
#  'x2t9OqTb4kE',
#  'zEv6JPtIS3U',
#  'hgG7xyGmKb0',
#  'KMB0Le9AdoY',
#  'Jn3BnljMu9M',
#  'DlPTG4AkuqU',
#  'KWFsCT27SBo',
#  'CR6yHCG9OmA',
#  'sskRz_lsY8g',
#  'kKD-4jlvsM8',
#  'uU4pjtcbFeg',
#  'lIkd_jt28i0',
#  'IuwWUvBkKzQ',
#  '4-Tzxj3EIIQ',
#  'dzPmX6jiuBs',
#  'feJZ5gJKF0I',
#  '1QAHGaw14P0',
#  'yvF5v-1lh9c',
#  'L1v9LcUyVGc',
#  'Lu3oIffvh7M']

# %%
stats = get_video_stats(video_ids)

# %%
len(stats)
# Out:
# 250

# %%
stats[0]
# Out:
# {'kind': 'youtube#video',
#  'etag': 'zLXGtGsZjK60lLgPi0J_n-svzKc',
#  'id': 'Wgw5ers5jA4',
#  'statistics': {'viewCount': '496',
#   'likeCount': '27',
#   'dislikeCount': '2',
#   'favoriteCount': '0',
#   'commentCount': '6'}}

# %%
most_disliked = sorted(stats, key=lambda x:int(x['statistics']['dislikeCount']),reverse=True)

# %%
most_disliked
# Out:
# [{'kind': 'youtube#video',
#   'etag': 'fCzfmR2pGzclbRtYf7KSzn74aN8',
#   'id': 'aKIFaFU2X00',
#   'statistics': {'viewCount': '30929',
#    'likeCount': '213',
#    'dislikeCount': '121',
#    'favoriteCount': '0',
#    'commentCount': '110'}},
#  {'kind': 'youtube#video',
#   'etag': 'k1-oEYpZN6BBodhiv8L1sC4DJRc',
#   'id': 'fmf_y8zpOgA',
#   'statistics': {'viewCount': '76846',
#    'likeCount': '1366',
#    'dislikeCount': '47',
#    'favoriteCount': '0',
#    'commentCount': '205'}},
#  {'kind': 'youtube#video',
#   'etag': 'iT8FJa3wPga8fqpf17wVeNHFCGU',
#   'id': 'BKK5NMDC0fk',
#   'statistics': {'viewCount': '57366',
#    'likeCount': '674',
#    'dislikeCount': '45',
#    'favoriteCount': '0',
#    'commentCount': '48'}},
#  {'kind': 'youtube#video',
#   'etag': 'DCSeZAxwel6TXMYVJwOslGhqgs4',
#   'id': '9G5vsZemFVM',
#   'statistics': {'viewCount': '42853',
#    'likeCount': '360',
#    'dislikeCount': '38',
#    'favoriteCount': '0',
#    'commentCount': '80'}},
#  {'kind': 'youtube#video',
#   'etag': 'OANEwOEKNc7LP-RL7DvioPEdPJc',
#   'id': 'jWh0FaRRZC4',
#   'statistics': {'viewCount': '97755',
#    'likeCount': '766',
#    'dislikeCount': '38',
#    'favoriteCount': '0',
#    'commentCount': '136'}},
#  {'kind': 'youtube#video',
#   'etag': 'ole__jvfwj4E6wDv_xJXXGBCbQc',
#   'id': 'BK7YvpTT4Sw',
#   'statistics': {'viewCount': '26293',
#    'likeCount': '324',
#    'dislikeCount': '34',
#    'favoriteCount': '0',
#    'commentCount': '64'}},
#  {'kind': 'youtube#video',
#   'etag': 'bNVdqpNutRXatB-uWdlTGxhrJlg',
#   'id': 'HRqxIizljgo',
#   'statistics': {'viewCount': '18078',
#    'likeCount': '164',
#    'dislikeCount': '32',
#    'favoriteCount': '0',
#    'commentCount': '23'}},
#  {'kind': 'youtube#video',
#   'etag': 'xLCNPSBRACS7kTt15axzXSWQTaI',
#   'id': '-QMg39gK624',
#   'statistics': {'viewCount': '31612',
#    'likeCount': '333',
#    'dislikeCount': '28',
#    'favoriteCount': '0',
#    'commentCount': '62'}},
#  {'kind': 'youtube#video',
#   'etag': 'HNrO-X7JDZUVzPz00dorzKEOnRA',
#   'id': 'hk3ubc1-ZGg',
#   'statistics': {'viewCount': '20624',
#    'likeCount': '140',
#    'dislikeCount': '28',
#    'favoriteCount': '0',
#    'commentCount': '42'}},
#  {'kind': 'youtube#video',
#   'etag': 'UClVe5Gv1cRb7EQ6LaOHL9UDQsY',
#   'id': 'GIywmJbGH-8',
#   'statistics': {'viewCount': '52440',
#    'likeCount': '773',
#    'dislikeCount': '19',
#    'favoriteCount': '0',
#    'commentCount': '56'}},
#  {'kind': 'youtube#video',
#   'etag': '2fmmcWWxDCzNVvoIXLS6ptU6S5g',
#   'id': '-mJXEzSD1Ic',
#   'statistics': {'viewCount': '28572',
#    'likeCount': '584',
#    'dislikeCount': '19',
#    'favoriteCount': '0',
#    'commentCount': '71'}},
#  {'kind': 'youtube#video',
#   'etag': 'KZhj-zBVR2POZSvcN4ZEYR_qlu8',
#   'id': 'cVzOEli3zaA',
#   'statistics': {'viewCount': '16225',
#    'likeCount': '389',
#    'dislikeCount': '19',
#    'favoriteCount': '0',
#    'commentCount': '49'}},
#  {'kind': 'youtube#video',
#   'etag': 'DeMvKrm4GLJDAnO15SSDRR4HPGs',
#   'id': '6i5bHQZ-c5U',
#   'statistics': {'viewCount': '27295',
#    'likeCount': '305',
#    'dislikeCount': '17',
#    'favoriteCount': '0',
#    'commentCount': '44'}},
#  {'kind': 'youtube#video',
#   'etag': 'Tvq0cKFqfnCRaVLknZq5-2tOeAE',
#   'id': 'ialnWPvouZ4',
#   'statistics': {'viewCount': '18565',
#    'likeCount': '255',
#    'dislikeCount': '17',
#    'favoriteCount': '0',
#    'commentCount': '22'}},
#  {'kind': 'youtube#video',
#   'etag': 'avSVZzDgnVCKFOIaSvgRxTfmbpg',
#   'id': 'JtKOP-ThcbU',
#   'statistics': {'viewCount': '31003',
#    'likeCount': '854',
#    'dislikeCount': '16',
#    'favoriteCount': '0',
#    'commentCount': '98'}},
#  {'kind': 'youtube#video',
#   'etag': 'jo3cXo9eUz5J9p6Wo8EpYSgP4b4',
#   'id': 'Xhw2l-hzoKk',
#   'statistics': {'viewCount': '20249',
#    'likeCount': '325',
#    'dislikeCount': '16',
#    'favoriteCount': '0',
#    'commentCount': '42'}},
#  {'kind': 'youtube#video',
#   'etag': 'hnIcuDzWVRE67IWIiPROibINAdQ',
#   'id': 'OggZfhyhDos',
#   'statistics': {'viewCount': '7823',
#    'likeCount': '138',
#    'dislikeCount': '15',
#    'favoriteCount': '0',
#    'commentCount': '22'}},
#  {'kind': 'youtube#video',
#   'etag': '7_4fXJxVoWtgq7I8PTAXp9aiQOQ',
#   'id': 'twuhocLtGCg',
#   'statistics': {'viewCount': '12358',
#    'likeCount': '187',
#    'dislikeCount': '14',
#    'favoriteCount': '0',
#    'commentCount': '34'}},
#  {'kind': 'youtube#video',
#   'etag': 'KMCLPQzzGwC1UHZCiRdy7O_3cEM',
#   'id': 'SpDI6-FvtJY',
#   'statistics': {'viewCount': '26192',
#    'likeCount': '219',
#    'dislikeCount': '13',
#    'favoriteCount': '0',
#    'commentCount': '28'}},
#  {'kind': 'youtube#video',
#   'etag': 'LumTd1g8SXPvdowWrYSv1Di6qtE',
#   'id': 'oD4IvH-Talo',
#   'statistics': {'viewCount': '10720',
#    'likeCount': '138',
#    'dislikeCount': '13',
#    'favoriteCount': '0',
#    'commentCount': '17'}},
#  {'kind': 'youtube#video',
#   'etag': 'lgBjvfgRWLeDbU6bTsFdDFHBfgI',
#   'id': 'DlPTG4AkuqU',
#   'statistics': {'viewCount': '21059',
#    'likeCount': '210',
#    'dislikeCount': '13',
#    'favoriteCount': '0',
#    'commentCount': '35'}},
#  {'kind': 'youtube#video',
#   'etag': 'wA8TuAjTro6p2M6hUL7y0cYI4tE',
#   'id': 'bytnxnZFLeg',
#   'statistics': {'viewCount': '19214',
#    'likeCount': '512',
#    'dislikeCount': '12',
#    'favoriteCount': '0',
#    'commentCount': '115'}},
#  {'kind': 'youtube#video',
#   'etag': 'rpeN8wft4cCycONwgWzXYlFy2Ko',
#   'id': '95p3cVkqYHQ',
#   'statistics': {'viewCount': '24482',
#    'likeCount': '228',
#    'dislikeCount': '12',
#    'favoriteCount': '0',
#    'commentCount': '34'}},
#  {'kind': 'youtube#video',
#   'etag': 'h-93bB17UITr6bCl_aDpMexFy7w',
#   'id': 'sskRz_lsY8g',
#   'statistics': {'viewCount': '14859',
#    'likeCount': '61',
#    'dislikeCount': '12',
#    'favoriteCount': '0',
#    'commentCount': '26'}},
#  {'kind': 'youtube#video',
#   'etag': 'R8FsWVjZmcV9iLjDtE7VHt-YDEE',
#   'id': 'kKl7scEW90c',
#   'statistics': {'viewCount': '11891',
#    'likeCount': '205',
#    'dislikeCount': '11',
#    'favoriteCount': '0',
#    'commentCount': '27'}},
#  {'kind': 'youtube#video',
#   'etag': 'l8vfoVD6QopreIx755-KmE_45pc',
#   'id': 'zTHtUm4AtcA',
#   'statistics': {'viewCount': '11679',
#    'likeCount': '264',
#    'dislikeCount': '11',
#    'favoriteCount': '0',
#    'commentCount': '18'}},
#  {'kind': 'youtube#video',
#   'etag': '7ruwgTCcSkvwI9pNIWCiZOprvxc',
#   'id': '2tWDA7SclXk',
#   'statistics': {'viewCount': '7215',
#    'likeCount': '67',
#    'dislikeCount': '11',
#    'favoriteCount': '0',
#    'commentCount': '14'}},
#  {'kind': 'youtube#video',
#   'etag': 'oIrUbw3t9vnDh92wpNNOlZqIZAo',
#   'id': 'oritw8qAR1U',
#   'statistics': {'viewCount': '3817',
#    'likeCount': '50',
#    'dislikeCount': '11',
#    'favoriteCount': '0',
#    'commentCount': '10'}},
#  {'kind': 'youtube#video',
#   'etag': 'dlOyQE3h2-0QamFa2Bbnl5Z4bng',
#   'id': 'RGSoVGtuHuA',
#   'statistics': {'viewCount': '26534',
#    'likeCount': '291',
#    'dislikeCount': '11',
#    'favoriteCount': '0',
#    'commentCount': '43'}},
#  {'kind': 'youtube#video',
#   'etag': 'QMdW4oy_E7Vok--DiFWcEGFSQFs',
#   'id': 'x2t9OqTb4kE',
#   'statistics': {'viewCount': '16801',
#    'likeCount': '93',
#    'dislikeCount': '11',
#    'favoriteCount': '0',
#    'commentCount': '6'}},
#  {'kind': 'youtube#video',
#   'etag': 'iUpvbr63puSvzyogylUksQPeCPc',
#   'id': 'hgG7xyGmKb0',
#   'statistics': {'viewCount': '6693',
#    'likeCount': '17',
#    'dislikeCount': '11',
#    'favoriteCount': '0',
#    'commentCount': '6'}},
#  {'kind': 'youtube#video',
#   'etag': 'O58RWA2yPhKmagiuXAHLwUsQBds',
#   'id': '-Zy18QEFm6s',
#   'statistics': {'viewCount': '9839',
#    'likeCount': '262',
#    'dislikeCount': '10',
#    'favoriteCount': '0',
#    'commentCount': '46'}},
#  {'kind': 'youtube#video',
#   'etag': 'c-SBBSeRxLZW4HsJAeWxeOX7fTc',
#   'id': 'hSuHnuNC8L4',
#   'statistics': {'viewCount': '10909',
#    'likeCount': '118',
#    'dislikeCount': '10',
#    'favoriteCount': '0',
#    'commentCount': '13'}},
#  {'kind': 'youtube#video',
#   'etag': 'l0XeAv55Ig_JAGaEgg3gNiwBWEU',
#   'id': 'uU4pjtcbFeg',
#   'statistics': {'viewCount': '24189',
#    'likeCount': '89',
#    'dislikeCount': '10',
#    'favoriteCount': '0',
#    'commentCount': '8'}},
#  {'kind': 'youtube#video',
#   'etag': 'clC0PAhx3wL_IXZW40NCC3UN_sc',
#   'id': 'EeUdel2AJ5g',
#   'statistics': {'viewCount': '22214',
#    'likeCount': '245',
#    'dislikeCount': '9',
#    'favoriteCount': '0',
#    'commentCount': '49'}},
#  {'kind': 'youtube#video',
#   'etag': 'oU0KefjEXdbf8GqqlP7AzFic_Jc',
#   'id': 'n3uSyqoBgQI',
#   'statistics': {'viewCount': '9707',
#    'likeCount': '244',
#    'dislikeCount': '9',
#    'favoriteCount': '0',
#    'commentCount': '69'}},
#  {'kind': 'youtube#video',
#   'etag': 'hD7NgZhtcBO8dTWC8AjW6Xd-LaQ',
#   'id': 'Q2CNZGEH59Q',
#   'statistics': {'viewCount': '12260',
#    'likeCount': '235',
#    'dislikeCount': '8',
#    'favoriteCount': '0',
#    'commentCount': '41'}},
#  {'kind': 'youtube#video',
#   'etag': '6pBD7kTyInyyr4L0oFX6p1lWpVI',
#   'id': 'zwMsmBsC1GM',
#   'statistics': {'viewCount': '18016',
#    'likeCount': '304',
#    'dislikeCount': '8',
#    'favoriteCount': '0',
#    'commentCount': '26'}},
#  {'kind': 'youtube#video',
#   'etag': '2pzzqXqWudxGd__OnffLu85tTOs',
#   'id': 'y85G7GLYhYA',
#   'statistics': {'viewCount': '6828',
#    'likeCount': '111',
#    'dislikeCount': '8',
#    'favoriteCount': '0',
#    'commentCount': '15'}},
#  {'kind': 'youtube#video',
#   'etag': 'KXD8LQL2sWnT28scN1iYsCQ8MfY',
#   'id': 'DTco1nTTlzE',
#   'statistics': {'viewCount': '8589',
#    'likeCount': '101',
#    'dislikeCount': '8',
#    'favoriteCount': '0',
#    'commentCount': '9'}},
#  {'kind': 'youtube#video',
#   'etag': 'jh0av08Ic9pYgtiNi75jufL_EYA',
#   'id': 'aFw8znSCqXM',
#   'statistics': {'viewCount': '12425',
#    'likeCount': '89',
#    'dislikeCount': '8',
#    'favoriteCount': '0',
#    'commentCount': '23'}},
#  {'kind': 'youtube#video',
#   'etag': 'UenAI7BRt_wxjWBRpAuK6e2uyss',
#   'id': 'GWdrL8dt1xQ',
#   'statistics': {'viewCount': '19100',
#    'likeCount': '252',
#    'dislikeCount': '8',
#    'favoriteCount': '0',
#    'commentCount': '66'}},
#  {'kind': 'youtube#video',
#   'etag': 'I-4nwXbBFmlKwO-P9THlutu8LdU',
#   'id': '2Mk6yPMFdFA',
#   'statistics': {'viewCount': '19595',
#    'likeCount': '141',
#    'dislikeCount': '8',
#    'favoriteCount': '0',
#    'commentCount': '17'}},
#  {'kind': 'youtube#video',
#   'etag': 'QEue07MrAzQ1OdhrkmCtq3eYdww',
#   'id': '2JGU9S2gCMg',
#   'statistics': {'viewCount': '10035',
#    'likeCount': '127',
#    'dislikeCount': '7',
#    'favoriteCount': '0',
#    'commentCount': '17'}},
#  {'kind': 'youtube#video',
#   'etag': '47Zncn5ElcWlFJJoGRt3IOUctjY',
#   'id': 'ruAownOJJKA',
#   'statistics': {'viewCount': '7497',
#    'likeCount': '112',
#    'dislikeCount': '7',
#    'favoriteCount': '0',
#    'commentCount': '23'}},
#  {'kind': 'youtube#video',
#   'etag': '4rZBIJ5KdFv38n0BRr9Q2uqPlE4',
#   'id': 'KMB0Le9AdoY',
#   'statistics': {'viewCount': '6217',
#    'likeCount': '25',
#    'dislikeCount': '7',
#    'favoriteCount': '0',
#    'commentCount': '30'}},
#  {'kind': 'youtube#video',
#   'etag': 'qlzhBQ6CtBw3gDmnjfjepeRYZ2k',
#   'id': 'Vc5kGYty18k',
#   'statistics': {'viewCount': '4590',
#    'likeCount': '123',
#    'dislikeCount': '6',
#    'favoriteCount': '0',
#    'commentCount': '12'}},
#  {'kind': 'youtube#video',
#   'etag': 'XAHyYhPwjnDijaUYcw-bmJf5pUk',
#   'id': 'VQnmcBnguPY',
#   'statistics': {'viewCount': '9197',
#    'likeCount': '173',
#    'dislikeCount': '6',
#    'favoriteCount': '0',
#    'commentCount': '40'}},
#  {'kind': 'youtube#video',
#   'etag': '7AF_FnPmRugVWPnK0-Jlmc3DI28',
#   'id': 'IBhdLRheKyM',
#   'statistics': {'viewCount': '7523',
#    'likeCount': '120',
#    'dislikeCount': '6',
#    'favoriteCount': '0',
#    'commentCount': '24'}},
#  {'kind': 'youtube#video',
#   'etag': 'GKfFccfzVFLjByn8ozKaHOLJbsU',
#   'id': 'LIcAmQec5K8',
#   'statistics': {'viewCount': '2562',
#    'likeCount': '38',
#    'dislikeCount': '6',
#    'favoriteCount': '0',
#    'commentCount': '4'}},
#  {'kind': 'youtube#video',
#   'etag': '5ZryAe_3x7dwt3ZnvKNkSaKf4Ds',
#   'id': 'xp1vX15inBg',
#   'statistics': {'viewCount': '6836',
#    'likeCount': '90',
#    'dislikeCount': '6',
#    'favoriteCount': '0',
#    'commentCount': '10'}},
#  {'kind': 'youtube#video',
#   'etag': 'ZOZeLsKBk5DEdM2MD_4k3DxQZjg',
#   'id': 'f77rKzqBzEA',
#   'statistics': {'viewCount': '2437',
#    'likeCount': '45',
#    'dislikeCount': '6',
#    'favoriteCount': '0',
#    'commentCount': '9'}},
#  {'kind': 'youtube#video',
#   'etag': 'MwvYWKuaLRHLZVKhEoAMQfR_j6c',
#   'id': 'SlrLZ1no08A',
#   'statistics': {'viewCount': '7673',
#    'likeCount': '92',
#    'dislikeCount': '6',
#    'favoriteCount': '0',
#    'commentCount': '8'}},
#  {'kind': 'youtube#video',
#   'etag': '01N9veKXudb6vwkEVV9HNMY_lk0',
#   'id': 'j1mh0or2CX8',
#   'statistics': {'viewCount': '15792',
#    'likeCount': '248',
#    'dislikeCount': '5',
#    'favoriteCount': '0',
#    'commentCount': '41'}},
#  {'kind': 'youtube#video',
#   'etag': 'Ao5Q4l18BGuSEN-nivj3GLDPni0',
#   'id': 'f3EVLwESJss',
#   'statistics': {'viewCount': '3616',
#    'likeCount': '57',
#    'dislikeCount': '5',
#    'favoriteCount': '0',
#    'commentCount': '10'}},
#  {'kind': 'youtube#video',
#   'etag': 'dF05d4PPCw39SQ8GpTTHmXOedqo',
#   'id': 'QP7pwaRA-LA',
#   'statistics': {'viewCount': '5348',
#    'likeCount': '71',
#    'dislikeCount': '5',
#    'favoriteCount': '0',
#    'commentCount': '5'}},
#  {'kind': 'youtube#video',
#   'etag': 'pbfboTSupRm-pwQjqT70fnb8ik4',
#   'id': '5gR6ObKkIeY',
#   'statistics': {'viewCount': '2582',
#    'likeCount': '49',
#    'dislikeCount': '5',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'gtn5i1l6qDOutqbvQF25YTq2gBk',
#   'id': 'XgohEG9fqNQ',
#   'statistics': {'viewCount': '7837',
#    'likeCount': '97',
#    'dislikeCount': '5',
#    'favoriteCount': '0',
#    'commentCount': '14'}},
#  {'kind': 'youtube#video',
#   'etag': '29XVv3SGb1HHkT4fK3dEk2D-2UY',
#   'id': 'gULdbWqbTIE',
#   'statistics': {'viewCount': '4654',
#    'likeCount': '108',
#    'dislikeCount': '4',
#    'favoriteCount': '0',
#    'commentCount': '16'}},
#  {'kind': 'youtube#video',
#   'etag': 'FG6gmagCom0JZCaHh0quNaj3jOA',
#   'id': 'vFiBKa4VbtU',
#   'statistics': {'viewCount': '1604',
#    'likeCount': '28',
#    'dislikeCount': '4',
#    'favoriteCount': '0',
#    'commentCount': '4'}},
#  {'kind': 'youtube#video',
#   'etag': 'FMR7jLMo9y42K6dZrE-EnMc4Ibg',
#   'id': 'Nr-gYadj5dw',
#   'statistics': {'viewCount': '5794',
#    'likeCount': '88',
#    'dislikeCount': '4',
#    'favoriteCount': '0',
#    'commentCount': '83'}},
#  {'kind': 'youtube#video',
#   'etag': '9BhgarMlL_lxwMN8tvkbTrfPDwE',
#   'id': 'c6uoxhaenHg',
#   'statistics': {'viewCount': '4313',
#    'likeCount': '75',
#    'dislikeCount': '4',
#    'favoriteCount': '0',
#    'commentCount': '5'}},
#  {'kind': 'youtube#video',
#   'etag': 'hmS9hlQLF3eg-_p7W9MJeYbjYqM',
#   'id': 'uBHOb55-fBo',
#   'statistics': {'viewCount': '3627',
#    'likeCount': '59',
#    'dislikeCount': '4',
#    'favoriteCount': '0',
#    'commentCount': '3'}},
#  {'kind': 'youtube#video',
#   'etag': 'E7l3j80IhKatnhWue-5_nSkpKTM',
#   'id': 'TQHDgyQ60B0',
#   'statistics': {'viewCount': '3751',
#    'likeCount': '69',
#    'dislikeCount': '4',
#    'favoriteCount': '0',
#    'commentCount': '8'}},
#  {'kind': 'youtube#video',
#   'etag': 'uxK8r-PuIF3bu5-45Z-RtOE0YdA',
#   'id': 'ek0FYB9zXJw',
#   'statistics': {'viewCount': '5316',
#    'likeCount': '87',
#    'dislikeCount': '4',
#    'favoriteCount': '0',
#    'commentCount': '6'}},
#  {'kind': 'youtube#video',
#   'etag': 'RIaApLdn5dC96X7YaV8Bq51Ydm4',
#   'id': 'kUxEInTQUhA',
#   'statistics': {'viewCount': '3060',
#    'likeCount': '40',
#    'dislikeCount': '4',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'fnZebt5T0lw6rQzdtuOdsvUtiKc',
#   'id': 'CR6yHCG9OmA',
#   'statistics': {'viewCount': '10537',
#    'likeCount': '23',
#    'dislikeCount': '4',
#    'favoriteCount': '0',
#    'commentCount': '18'}},
#  {'kind': 'youtube#video',
#   'etag': '0-Ca0suLqxHCf6wnAFOQqC9R6Q8',
#   'id': 'Rw4hrXQi1CI',
#   'statistics': {'viewCount': '675',
#    'likeCount': '14',
#    'dislikeCount': '3',
#    'favoriteCount': '0',
#    'commentCount': '4'}},
#  {'kind': 'youtube#video',
#   'etag': 'DcTRc8YSotRQ0x4pCwzw8qlScKg',
#   'id': 'hMIoc2wxTug',
#   'statistics': {'viewCount': '1718',
#    'likeCount': '38',
#    'dislikeCount': '3',
#    'favoriteCount': '0',
#    'commentCount': '9'}},
#  {'kind': 'youtube#video',
#   'etag': '_I_1SoN3jasPLqnyYzhGBmpnv90',
#   'id': 'ELcNjenTpCo',
#   'statistics': {'viewCount': '1546',
#    'likeCount': '90',
#    'dislikeCount': '3',
#    'favoriteCount': '0',
#    'commentCount': '27'}},
#  {'kind': 'youtube#video',
#   'etag': 'CyBpmy257Puh_xUmjccgmFAoVZc',
#   'id': 'DSSvVd1uo8o',
#   'statistics': {'viewCount': '1797',
#    'likeCount': '47',
#    'dislikeCount': '3',
#    'favoriteCount': '0',
#    'commentCount': '6'}},
#  {'kind': 'youtube#video',
#   'etag': 'MFbO7Rr480NCLWZu73n0YFROD68',
#   'id': '7CpRn3d1z_g',
#   'statistics': {'viewCount': '999',
#    'likeCount': '21',
#    'dislikeCount': '3',
#    'favoriteCount': '0',
#    'commentCount': '8'}},
#  {'kind': 'youtube#video',
#   'etag': 'YjtYOSDhHD_BtkdeE6vxzTVWTvg',
#   'id': 'cUx9qUkYJgk',
#   'statistics': {'viewCount': '5714',
#    'likeCount': '78',
#    'dislikeCount': '3',
#    'favoriteCount': '0',
#    'commentCount': '37'}},
#  {'kind': 'youtube#video',
#   'etag': 'Eyp9z1Rf-5gLMYAGHV8-Byw5Nt8',
#   'id': 'IK5UUrPglTM',
#   'statistics': {'viewCount': '9421',
#    'likeCount': '160',
#    'dislikeCount': '3',
#    'favoriteCount': '0',
#    'commentCount': '39'}},
#  {'kind': 'youtube#video',
#   'etag': 'VCodWrEpJipkje8oEUhrTkei4bg',
#   'id': 'sCneLptDZ4I',
#   'statistics': {'viewCount': '3038',
#    'likeCount': '38',
#    'dislikeCount': '3',
#    'favoriteCount': '0',
#    'commentCount': '6'}},
#  {'kind': 'youtube#video',
#   'etag': 'uitG4JvKa4vbyRSzEztHfZAklKE',
#   'id': 'QSwXIIkxPcQ',
#   'statistics': {'viewCount': '1889',
#    'likeCount': '44',
#    'dislikeCount': '3',
#    'favoriteCount': '0',
#    'commentCount': '4'}},
#  {'kind': 'youtube#video',
#   'etag': '7m8Ab1tJvUhw_2JkojDLPke5lDA',
#   'id': 'pHliYIPnxZU',
#   'statistics': {'viewCount': '1936',
#    'likeCount': '34',
#    'dislikeCount': '3',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'ZZCMs7iLm8LQoHn2B3esxQBO4G8',
#   'id': 'dTRXjoVq_RE',
#   'statistics': {'viewCount': '2988',
#    'likeCount': '40',
#    'dislikeCount': '3',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': '2-iZ0Itcg53seLlNjsqBRaHjQcI',
#   'id': 'FInLfuYzJhA',
#   'statistics': {'viewCount': '4672',
#    'likeCount': '65',
#    'dislikeCount': '3',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'ET5mj1GWLcI9kqV0VkLXpYzu7bM',
#   'id': 'zEv6JPtIS3U',
#   'statistics': {'viewCount': '2261',
#    'likeCount': '12',
#    'dislikeCount': '3',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': 'ZaCG_C4KpOcv0rA7EgXNgY1S4K4',
#   'id': 'kKD-4jlvsM8',
#   'statistics': {'viewCount': '12153',
#    'likeCount': '36',
#    'dislikeCount': '3',
#    'favoriteCount': '0',
#    'commentCount': '5'}},
#  {'kind': 'youtube#video',
#   'etag': 'i-JfCwAkLOhhAgmfqdzpOTrGt6E',
#   'id': 'lIkd_jt28i0',
#   'statistics': {'viewCount': '1899',
#    'likeCount': '27',
#    'dislikeCount': '3',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'NzAjtUtMDhZD0n1hllCqJhb7TkE',
#   'id': 'yvF5v-1lh9c',
#   'statistics': {'viewCount': '1152',
#    'likeCount': '8',
#    'dislikeCount': '3',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'zLXGtGsZjK60lLgPi0J_n-svzKc',
#   'id': 'Wgw5ers5jA4',
#   'statistics': {'viewCount': '496',
#    'likeCount': '27',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '6'}},
#  {'kind': 'youtube#video',
#   'etag': 'J4JBKI25VBq8doNBaYbOtLZrB2U',
#   'id': 'my2vBYZ1RFw',
#   'statistics': {'viewCount': '879',
#    'likeCount': '38',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '6'}},
#  {'kind': 'youtube#video',
#   'etag': 'J7jMwhc0kxqVrlxXP-eLxBEU-Zk',
#   'id': 'U4dSWJFIQ0A',
#   'statistics': {'viewCount': '1308',
#    'likeCount': '31',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '9'}},
#  {'kind': 'youtube#video',
#   'etag': 'TyJGWne-Ahf7DzXEqSk-A0FdBvw',
#   'id': 'sTr30oviyHc',
#   'statistics': {'viewCount': '879',
#    'likeCount': '21',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '4'}},
#  {'kind': 'youtube#video',
#   'etag': 'TWPLL8Zi_DAbXZ7_Iv0h1Wc2904',
#   'id': 'uJC8A_7VZOA',
#   'statistics': {'viewCount': '4448',
#    'likeCount': '87',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '12'}},
#  {'kind': 'youtube#video',
#   'etag': 'RkGL80A6BUXp3i7YX-Nv8DZbNRY',
#   'id': 'xeeUgn08F94',
#   'statistics': {'viewCount': '2404',
#    'likeCount': '59',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '13'}},
#  {'kind': 'youtube#video',
#   'etag': 'zCxQsL9Yonzt7pfAndrYzNUyheA',
#   'id': 'sH5XSdXksAg',
#   'statistics': {'viewCount': '1108',
#    'likeCount': '31',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'nzSAvWNK7yqPUCBPtwlpD-B2DNg',
#   'id': '7tYEsT2dzlo',
#   'statistics': {'viewCount': '2149',
#    'likeCount': '53',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '18'}},
#  {'kind': 'youtube#video',
#   'etag': 'mUz8LjjZxHsRK_Hx_ymOJ34So2M',
#   'id': 'HiillVo1gJY',
#   'statistics': {'viewCount': '12055',
#    'likeCount': '261',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '61'}},
#  {'kind': 'youtube#video',
#   'etag': 'Cw5d_jVo71fgzMUKH_PUoyAGLWY',
#   'id': '_uPsxnIg0uU',
#   'statistics': {'viewCount': '863',
#    'likeCount': '29',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '8'}},
#  {'kind': 'youtube#video',
#   'etag': 'JLK-q5Lpm6GD5rsMwqHWl7OoLlI',
#   'id': 'Mf-4Zcz5VKw',
#   'statistics': {'viewCount': '1270',
#    'likeCount': '15',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '3'}},
#  {'kind': 'youtube#video',
#   'etag': 'ZnuktPRdmzkf1_ryWqBcTdG9aJw',
#   'id': 'MoeXYCV830E',
#   'statistics': {'viewCount': '1169',
#    'likeCount': '19',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'GweR8rtKy95omLeiYuBRGxmcWA0',
#   'id': 'KTaLs494xgo',
#   'statistics': {'viewCount': '3021',
#    'likeCount': '37',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'OVfmY6JNQM8H85r9gWLO0LO0ovk',
#   'id': 'ZPM8TCz5cd8',
#   'statistics': {'viewCount': '778',
#    'likeCount': '13',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'KQCuO8WEJQuUNWa-qEC68iTGoYs',
#   'id': 'oU86kvDbSNw',
#   'statistics': {'viewCount': '2106',
#    'likeCount': '22',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'iWIKaJGDTjZvPYvN1dVd7dDhECo',
#   'id': 'Hh47pBRkhns',
#   'statistics': {'viewCount': '1666',
#    'likeCount': '46',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '4'}},
#  {'kind': 'youtube#video',
#   'etag': 'L9sjknXBFndxQRSujjdDpggmyr4',
#   'id': 'oS5PahnKf_E',
#   'statistics': {'viewCount': '3204',
#    'likeCount': '40',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '6'}},
#  {'kind': 'youtube#video',
#   'etag': '8d0Yp6wBhtt-G7YxYc686-NbM7g',
#   'id': '4W06lWibPyc',
#   'statistics': {'viewCount': '7079',
#    'likeCount': '43',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '10'}},
#  {'kind': 'youtube#video',
#   'etag': 'R1YnAByGWie8CpbCuTPtKs-_89g',
#   'id': 'K4aZuBeG8fU',
#   'statistics': {'viewCount': '1084',
#    'likeCount': '30',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '13'}},
#  {'kind': 'youtube#video',
#   'etag': 'R3QFEqzMhmONRzrcA-ET26XbMm0',
#   'id': 'IKRFY5uFoOQ',
#   'statistics': {'viewCount': '1802',
#    'likeCount': '35',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '8'}},
#  {'kind': 'youtube#video',
#   'etag': 'tgTfwFZSVe0X8iUSPde471LRMIM',
#   'id': 'NcaMLIUpjbY',
#   'statistics': {'viewCount': '6721',
#    'likeCount': '134',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '14'}},
#  {'kind': 'youtube#video',
#   'etag': 'ioIEh-2sRvOg_e0K6d8EzfDqINw',
#   'id': '_sS5s0Nd-qc',
#   'statistics': {'viewCount': '2168',
#    'likeCount': '42',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': 'j-VD-2MvHJL1Ly9fQmd49AxGFjE',
#   'id': 'axVcw9WWZz4',
#   'statistics': {'viewCount': '1625',
#    'likeCount': '30',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': '9DKjMp2EKuz_94YdUAmnU1idVg0',
#   'id': '0y0V0ObEhoo',
#   'statistics': {'viewCount': '2925',
#    'likeCount': '34',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '7'}},
#  {'kind': 'youtube#video',
#   'etag': 'JpgPzd6ShnGPgaG7W7FUVKKxfR0',
#   'id': 'op3tFHLbMas',
#   'statistics': {'viewCount': '5553',
#    'likeCount': '90',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '12'}},
#  {'kind': 'youtube#video',
#   'etag': '8auOJwPgRjEISAZ1ZyhTd9WDurI',
#   'id': 'clT8wH_Us5g',
#   'statistics': {'viewCount': '1593',
#    'likeCount': '49',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '4'}},
#  {'kind': 'youtube#video',
#   'etag': 'uutRG6Wc-z9QUPUtkhIQqWJO990',
#   'id': 'wN43Iypd_MA',
#   'statistics': {'viewCount': '2539',
#    'likeCount': '71',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '15'}},
#  {'kind': 'youtube#video',
#   'etag': 'm4sPTedpEguhfudLbXYA_K8-Vy0',
#   'id': 'j5KwP4ifHWs',
#   'statistics': {'viewCount': '1843',
#    'likeCount': '41',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '7'}},
#  {'kind': 'youtube#video',
#   'etag': '9kT_KVgjHIUHo979qgvAK2iWQBY',
#   'id': '3aHJmbosJYs',
#   'statistics': {'viewCount': '163',
#    'likeCount': '11',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'YgV2Sa5y1ravecqA2Qtnr4PtQfQ',
#   'id': 'e29Aj6tJ_5k',
#   'statistics': {'viewCount': '7605',
#    'likeCount': '40',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '21'}},
#  {'kind': 'youtube#video',
#   'etag': 'H-BqfcNSLgs0gGeq4Fsd7gzvgxE',
#   'id': 'Jn3BnljMu9M',
#   'statistics': {'viewCount': '6154',
#    'likeCount': '22',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'UAGh6UGayJcQnBplCEsgQo5_4zE',
#   'id': 'KWFsCT27SBo',
#   'statistics': {'viewCount': '7508',
#    'likeCount': '41',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '18'}},
#  {'kind': 'youtube#video',
#   'etag': 'g_q1jee8DU5H1Dto8M_Ov8pY42E',
#   'id': 'Lu3oIffvh7M',
#   'statistics': {'viewCount': '333',
#    'likeCount': '7',
#    'dislikeCount': '2',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': 'FgZqr-z4MRGryJm_63xSKp_go0c',
#   'id': 'Jztj_yuFTlk',
#   'statistics': {'viewCount': '723',
#    'likeCount': '30',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '4'}},
#  {'kind': 'youtube#video',
#   'etag': 'PTu41uo1esXCziQ_Js3OozC2sQQ',
#   'id': '8O8VNuYyplU',
#   'statistics': {'viewCount': '674',
#    'likeCount': '11',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '3'}},
#  {'kind': 'youtube#video',
#   'etag': 'dkgeTEKWxIBM341g0ldszYkdtwY',
#   'id': 'I93i7KGggcg',
#   'statistics': {'viewCount': '1187',
#    'likeCount': '18',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '4'}},
#  {'kind': 'youtube#video',
#   'etag': 'KZjHWvtvyzvEeXAB295PNi2EX1o',
#   'id': 'BiV-kdQbEo0',
#   'statistics': {'viewCount': '631',
#    'likeCount': '9',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'CI0Ox6Z0a8cC9_6cpZgHE75WTqY',
#   'id': 'bw1gfnLSmd0',
#   'statistics': {'viewCount': '1096',
#    'likeCount': '22',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '8'}},
#  {'kind': 'youtube#video',
#   'etag': '27CvjQdvchTs-uD-8aXrFIBwMZo',
#   'id': 'xZXsR7soexU',
#   'statistics': {'viewCount': '443',
#    'likeCount': '20',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '3'}},
#  {'kind': 'youtube#video',
#   'etag': 'zA1nXohtq1gJK3p9F3JgJDVXEHs',
#   'id': 'vDxrmKOJMJ8',
#   'statistics': {'viewCount': '966',
#    'likeCount': '7',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '4'}},
#  {'kind': 'youtube#video',
#   'etag': 'HnCP0KbVI4bdMjGWm5L76l8qDts',
#   'id': 'Ks9HWZWMsw4',
#   'statistics': {'viewCount': '2882',
#    'likeCount': '44',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '6'}},
#  {'kind': 'youtube#video',
#   'etag': 'lS1dOKOhM0CmnFGTRGKL-cXilDU',
#   'id': 'BvbqI6eDh0c',
#   'statistics': {'viewCount': '8132',
#    'likeCount': '118',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '11'}},
#  {'kind': 'youtube#video',
#   'etag': 'eLTHfiIIDPttSat1ql3kuqHJJSw',
#   'id': '4ho21Wppf30',
#   'statistics': {'viewCount': '12361',
#    'likeCount': '139',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '53'}},
#  {'kind': 'youtube#video',
#   'etag': '1mKGquvw04ywE34-BHOktWf0HZI',
#   'id': 'k7_pSwjieiQ',
#   'statistics': {'viewCount': '1675',
#    'likeCount': '38',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '7'}},
#  {'kind': 'youtube#video',
#   'etag': 'U-X82-vmuz296SkRui7Wil7RuVg',
#   'id': '6zge0N962aw',
#   'statistics': {'viewCount': '3591',
#    'likeCount': '126',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '25'}},
#  {'kind': 'youtube#video',
#   'etag': 'vC4nqvO3mEp4ilng0eW-UjaDCYE',
#   'id': 'MUXEuOJAm2Q',
#   'statistics': {'viewCount': '1188',
#    'likeCount': '14',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '4'}},
#  {'kind': 'youtube#video',
#   'etag': 'cIw3zY0hkey5P5AYRUc-iQFCP_Y',
#   'id': 'fB8GLixWRrY',
#   'statistics': {'viewCount': '698',
#    'likeCount': '15',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'WUJsqcEBXg5QtYdY3DFL0yeSEP8',
#   'id': 'PV4TdArivCk',
#   'statistics': {'viewCount': '879',
#    'likeCount': '7',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'o8tZG-43XqKEWnacVWrPszOYlac',
#   'id': 'j0GRmMh74yw',
#   'statistics': {'viewCount': '796',
#    'likeCount': '17',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '11'}},
#  {'kind': 'youtube#video',
#   'etag': '8Sp7QSK_ieHLotU8fLN-oSSHGO8',
#   'id': 'ivK4ImvhUfo',
#   'statistics': {'viewCount': '1396',
#    'likeCount': '15',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': 'RmXwc93UIMQPvVZRa7HoUtDFpTs',
#   'id': 'Qf1gIpmHK6Y',
#   'statistics': {'viewCount': '223',
#    'likeCount': '4',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': '_26Vu6monGxwSrjJcM530E7KoO0',
#   'id': 'JRXhCmmLbeY',
#   'statistics': {'viewCount': '1443',
#    'likeCount': '22',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '5'}},
#  {'kind': 'youtube#video',
#   'etag': '-kNPkZL4qp2DcjQiO1B3p4YdFPo',
#   'id': 'DEqIiH_bkFc',
#   'statistics': {'viewCount': '831',
#    'likeCount': '23',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '5'}},
#  {'kind': 'youtube#video',
#   'etag': '3k4sbNfz6JKojOCw7HCKJDllv74',
#   'id': 'L5TBwa9sD78',
#   'statistics': {'viewCount': '736',
#    'likeCount': '14',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'h81tGnrjwBZJWsqCYSGW4dSnbHY',
#   'id': 'cymDVY_pkYo',
#   'statistics': {'viewCount': '2272',
#    'likeCount': '21',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'PoVpn7Hj_WP2_GROi9D-sf9LZnc',
#   'id': '6f6dTBQXa8Y',
#   'statistics': {'viewCount': '1635',
#    'likeCount': '81',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '8'}},
#  {'kind': 'youtube#video',
#   'etag': '06ypGBtKMUQep0cXCNr4miUWMpY',
#   'id': 'PeSXwg72_KE',
#   'statistics': {'viewCount': '840',
#    'likeCount': '24',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '4'}},
#  {'kind': 'youtube#video',
#   'etag': '-U9ciDO81dvI_dZ1C3LK3xE2pKE',
#   'id': 'sPJ28bdBH-w',
#   'statistics': {'viewCount': '2973',
#    'likeCount': '46',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '8'}},
#  {'kind': 'youtube#video',
#   'etag': 'W0s5R3JlfRR_mtdzVeWHgGwP0Zw',
#   'id': '_JdUzQFFLn0',
#   'statistics': {'viewCount': '499',
#    'likeCount': '14',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': 'VTU37VlGIgOD5R-XCJsqpTAgJ_E',
#   'id': '5ff4_YK83fQ',
#   'statistics': {'viewCount': '3602',
#    'likeCount': '48',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '4'}},
#  {'kind': 'youtube#video',
#   'etag': 'wOJIuSUwDFJzcKhVPpkUQrnRE2I',
#   'id': 'WIz9KRii2Lk',
#   'statistics': {'viewCount': '613',
#    'likeCount': '11',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'o4g4dewxtTY5L5v4l4JjdMGT2hI',
#   'id': 'PQXfVo0jIo4',
#   'statistics': {'viewCount': '1068',
#    'likeCount': '21',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'khLmUBh_Q_NKkazIAWjZKAOpqUk',
#   'id': 'WSLtyzjsIY4',
#   'statistics': {'viewCount': '1244',
#    'likeCount': '23',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '7'}},
#  {'kind': 'youtube#video',
#   'etag': 'zWQUHQL3Dsc5Ue9lirlJvVXeB0M',
#   'id': '-3PUuhLekbk',
#   'statistics': {'viewCount': '1139',
#    'likeCount': '15',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': 'qc2bvOxtDqHsdhVn61y9jH4Jx9M',
#   'id': 'Ju4xkvFm07o',
#   'statistics': {'viewCount': '2092',
#    'likeCount': '24',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '6'}},
#  {'kind': 'youtube#video',
#   'etag': 'mXh1nctznva1kvaza2JUxtWZRIc',
#   'id': 'lTdX45rle7A',
#   'statistics': {'viewCount': '1117',
#    'likeCount': '21',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': 'L9vEWETy-_ly5Qk_jpnACBaIKok',
#   'id': 'ya8FfxkKN4g',
#   'statistics': {'viewCount': '176',
#    'likeCount': '12',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '3'}},
#  {'kind': 'youtube#video',
#   'etag': 'BkkEenULr_lPLRCOTTbFSXVLEfs',
#   'id': '2CvzoNPSOHg',
#   'statistics': {'viewCount': '3781',
#    'likeCount': '82',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '9'}},
#  {'kind': 'youtube#video',
#   'etag': 'GzzbSsJhcPUYp35H1Ie7FTKpqGA',
#   'id': 'f4Q-L4vGdh8',
#   'statistics': {'viewCount': '776',
#    'likeCount': '19',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': 'CUQOKxpLkGfihNcRSwqTAq0-bww',
#   'id': 'b_jOJNUD350',
#   'statistics': {'viewCount': '13760',
#    'likeCount': '230',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '38'}},
#  {'kind': 'youtube#video',
#   'etag': 'XWwu-mFKjWsmEMiofrnulVuSFvg',
#   'id': 'H4fQUHVvbX8',
#   'statistics': {'viewCount': '5850',
#    'likeCount': '102',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '20'}},
#  {'kind': 'youtube#video',
#   'etag': '6pNAlzVxetCVL2ZXaAmNSbWDyT8',
#   'id': 'wq570TYG-eg',
#   'statistics': {'viewCount': '3335',
#    'likeCount': '67',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '26'}},
#  {'kind': 'youtube#video',
#   'etag': 'ceV7aj6w0I56vM6zkIMrDxeoQ7k',
#   'id': 'yDWCfEbgyBo',
#   'statistics': {'viewCount': '1291',
#    'likeCount': '33',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'dVI2NbX5wMb19GTRGEK-61rZvsU',
#   'id': 'EsUTO4Xzehg',
#   'statistics': {'viewCount': '3765',
#    'likeCount': '93',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '10'}},
#  {'kind': 'youtube#video',
#   'etag': 'hJfR_vTaXNFnp34BioyK_Oi8M-w',
#   'id': 'T4oLluJaCIE',
#   'statistics': {'viewCount': '511',
#    'likeCount': '14',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'WKqjNPdLBE6OJ0XjXMJKrzq4IBU',
#   'id': 'luMnpyKR6C0',
#   'statistics': {'viewCount': '5392',
#    'likeCount': '43',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '5'}},
#  {'kind': 'youtube#video',
#   'etag': 'BbMICk9UtNP_7o8sqDGhyyjWf60',
#   'id': 's6C3kYCNmLc',
#   'statistics': {'viewCount': '1346',
#    'likeCount': '37',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '3'}},
#  {'kind': 'youtube#video',
#   'etag': '5XJ24_M0z4DGrzHzaKceTVRijKA',
#   'id': 'B55roI7rE_Y',
#   'statistics': {'viewCount': '3762',
#    'likeCount': '48',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '7'}},
#  {'kind': 'youtube#video',
#   'etag': 'tGijHMo9vsMQ62XF_m_MYpOee44',
#   'id': 'GO460-dGTdU',
#   'statistics': {'viewCount': '1260',
#    'likeCount': '20',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': 'g9xn15cTFUHNFUNKy3viR_nES0g',
#   'id': 'oGbX05orp2A',
#   'statistics': {'viewCount': '1518',
#    'likeCount': '32',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': '-vRn14_VU81aqFkMl-YSv1Xvb7M',
#   'id': 'J-o99pzbBJk',
#   'statistics': {'viewCount': '3526',
#    'likeCount': '58',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '19'}},
#  {'kind': 'youtube#video',
#   'etag': 'BVEniMztirXM7vs5qe8m6sPKcjI',
#   'id': 'BX9BTQf9-Fc',
#   'statistics': {'viewCount': '3230',
#    'likeCount': '29',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'knCvTh39YPZctW6vagNk0KpX_T8',
#   'id': '8GRUwftKAps',
#   'statistics': {'viewCount': '2323',
#    'likeCount': '42',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '10'}},
#  {'kind': 'youtube#video',
#   'etag': '2vqShJSBKkkgHN4_Gl5891ZXIzQ',
#   'id': 'ym4V6yZh4yU',
#   'statistics': {'viewCount': '358',
#    'likeCount': '11',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '3'}},
#  {'kind': 'youtube#video',
#   'etag': 'LUfbvrhc0qglBKC8AiM5F4yEhNs',
#   'id': '_3n0AiYP5DU',
#   'statistics': {'viewCount': '962',
#    'likeCount': '15',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'A4iOBPxQTfD0soe_Fa2wvNWOtCM',
#   'id': 'YJ1loqmAKpk',
#   'statistics': {'viewCount': '963',
#    'likeCount': '22',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'VxIgFyjyqdsO4evRAg-zwFb9yWw',
#   'id': 'cefqrkkWOnM',
#   'statistics': {'viewCount': '102',
#    'likeCount': '6',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'dCfKia4fHWwPHD_GHWM3chwaGBw',
#   'id': 'IuwWUvBkKzQ',
#   'statistics': {'viewCount': '2225',
#    'likeCount': '5',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'T5RjBCGzZlPQxju6K7JGOCkrDkc',
#   'id': '4-Tzxj3EIIQ',
#   'statistics': {'viewCount': '4331',
#    'likeCount': '6',
#    'dislikeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'KrWxnjiyHokLVfTkntHM8yDACyQ',
#   'id': 'WTofttoD2xg',
#   'statistics': {'viewCount': '1761',
#    'likeCount': '63',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '7'}},
#  {'kind': 'youtube#video',
#   'etag': 'u7G4ZJfzRciQbJ6mrAMXZnorGIE',
#   'id': 'oYFzQB9zj5I',
#   'statistics': {'viewCount': '402',
#    'likeCount': '13',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': '3S9ZfDlFdmaitrDmK1gMx6n6cb4',
#   'id': 'vHMvobBbQJc',
#   'statistics': {'viewCount': '348',
#    'likeCount': '10',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '3'}},
#  {'kind': 'youtube#video',
#   'etag': 'MeL3bLM9iEh1A74J8cb3BSJV8es',
#   'id': 'dT9ymsYVVu8',
#   'statistics': {'viewCount': '441',
#    'likeCount': '7',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'yuxgrWrioJcpIsr1rPz3kw-e2zg',
#   'id': 'FbfV9N_va7Y',
#   'statistics': {'viewCount': '475',
#    'likeCount': '8',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'P8kGKsuM11mAWx8b53pDY-LvP6Q',
#   'id': 'ckNUeTNBwT4',
#   'statistics': {'viewCount': '1121',
#    'likeCount': '16',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '12'}},
#  {'kind': 'youtube#video',
#   'etag': 'Ky53Igln7xJo5lWonDcYlxibCDg',
#   'id': 'DiXRBYi1KDI',
#   'statistics': {'viewCount': '620',
#    'likeCount': '9',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'PSdlAKRxWTUXvn_cvKjrvMWS-9c',
#   'id': '8NW2IzfoY2Y',
#   'statistics': {'viewCount': '885',
#    'likeCount': '8',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 't_1Gc-Pqkri4TO_V2GFXdZOJJGY',
#   'id': 'PHX1kraTTrE',
#   'statistics': {'viewCount': '1155',
#    'likeCount': '13',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'v2A9B0PyF3oYA_3L6xPK3aF4ES0',
#   'id': '95y1N6MFCNs',
#   'statistics': {'viewCount': '916',
#    'likeCount': '36',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '11'}},
#  {'kind': 'youtube#video',
#   'etag': 'HJKee3xd33CKUM7T2dgtUyKdaCw',
#   'id': 'hCJpNPsS54Y',
#   'statistics': {'viewCount': '1079',
#    'likeCount': '42',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '11'}},
#  {'kind': 'youtube#video',
#   'etag': 'YtYMTjKC879yHzS7fIW3Iv7NpzQ',
#   'id': '9n4uJG_Qg44',
#   'statistics': {'viewCount': '1311',
#    'likeCount': '33',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '12'}},
#  {'kind': 'youtube#video',
#   'etag': 'Aj-DafHyHHooj4gRzphon-U_QLc',
#   'id': 'xoQ7TdB-9NI',
#   'statistics': {'viewCount': '1383',
#    'likeCount': '31',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'd9ZSHN-DUCq-E6hq5JSWKuThtis',
#   'id': 'r4Z7kmsauTA',
#   'statistics': {'viewCount': '922',
#    'likeCount': '20',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '5'}},
#  {'kind': 'youtube#video',
#   'etag': 'zjeQpQI7pJF_OvhO5yeaBTldy3Q',
#   'id': 'tD-dZjDWTZI',
#   'statistics': {'viewCount': '852',
#    'likeCount': '24',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '3'}},
#  {'kind': 'youtube#video',
#   'etag': 'YVCGk-EVQFQTDO9Aa9dmK95M7pM',
#   'id': 'DQNEj26i6og',
#   'statistics': {'viewCount': '746',
#    'likeCount': '17',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '9'}},
#  {'kind': 'youtube#video',
#   'etag': 'pfgOZMyuYXi0Vqp2qAtLlotRTlY',
#   'id': '1kwXDCCcvvE',
#   'statistics': {'viewCount': '739',
#    'likeCount': '16',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '6'}},
#  {'kind': 'youtube#video',
#   'etag': 'PKuLbBXYJ6R1eLesbEamjwsTryc',
#   'id': '2_IogBzts-M',
#   'statistics': {'viewCount': '851',
#    'likeCount': '15',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': '-gct6NXDeQ9nPDlwcdVP5Y0w3xU',
#   'id': 'a_LRNBFVCq8',
#   'statistics': {'viewCount': '794',
#    'likeCount': '17',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'qV-WvKqftNpFm0jKmdKwcf7CzKI',
#   'id': 'WO2s7jUF5mk',
#   'statistics': {'viewCount': '773',
#    'likeCount': '13',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '3'}},
#  {'kind': 'youtube#video',
#   'etag': 'H59fskTUf4_Jh0xR95DTjo29zvw',
#   'id': 'fujPIABgUD0',
#   'statistics': {'viewCount': '927',
#    'likeCount': '27',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '4'}},
#  {'kind': 'youtube#video',
#   'etag': 'ijsVfhdrnT8Ib7MJVDlnft-ItH0',
#   'id': 'FXhbksjm3Ec',
#   'statistics': {'viewCount': '501',
#    'likeCount': '13',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '3'}},
#  {'kind': 'youtube#video',
#   'etag': 'JksnvU6muAKa97bMOEK7ddFs60A',
#   'id': '6WTFF-mKZX8',
#   'statistics': {'viewCount': '1230',
#    'likeCount': '20',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'RduSp3X2RWNQ-50TNAs7q5e_jL0',
#   'id': 'NEOSf7VKTTc',
#   'statistics': {'viewCount': '450',
#    'likeCount': '8',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': 'U-zo0XEwaLJMVBS-lccQ_3_HpKo',
#   'id': '8wRfskrpTIk',
#   'statistics': {'viewCount': '1156',
#    'likeCount': '21',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '4'}},
#  {'kind': 'youtube#video',
#   'etag': 'hMFyPfbEoAZMRzC66M6xDTQn4dc',
#   'id': 'aAbQTODpats',
#   'statistics': {'viewCount': '366',
#    'likeCount': '8',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': 'kbpgTWr6jWzJKykwuIMwHqSCcxU',
#   'id': '2wME30BZuFY',
#   'statistics': {'viewCount': '418',
#    'likeCount': '8',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'Lp4uchl6NcYtr46rxEwQXt5xtS0',
#   'id': 'dl9K13PCdJ0',
#   'statistics': {'viewCount': '485',
#    'likeCount': '14',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'dy4tIT0j1OW63_OSbOGFDqgNE7M',
#   'id': 'AzKV9NbtNJ0',
#   'statistics': {'viewCount': '863',
#    'likeCount': '19',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '6'}},
#  {'kind': 'youtube#video',
#   'etag': 'ggqui45VbM5APpkayUxN35_rvqw',
#   'id': 'jhqODb3Rpxo',
#   'statistics': {'viewCount': '348',
#    'likeCount': '9',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': 'BgVaKyTkcBIRj-wvj01MH5u5Jl4',
#   'id': 'wMypio8N95k',
#   'statistics': {'viewCount': '293',
#    'likeCount': '3',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'hLCRrJvwm0YM-ZQl1K8cS9Kxb9o',
#   'id': 'ZVfLGUpKuwQ',
#   'statistics': {'viewCount': '209',
#    'likeCount': '4',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': 'SryRy7e4N14R3bDMMrrC_H8ZyZg',
#   'id': '65fBlCJ_vVg',
#   'statistics': {'viewCount': '413',
#    'likeCount': '9',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'W369D4NIlDaTU3v8w5VB8yvrqJk',
#   'id': '9iRcu2VKsIg',
#   'statistics': {'viewCount': '532',
#    'likeCount': '9',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': '5b932AuU-dKCyFGsqC9DQ2vdwEY',
#   'id': '6pipGjJZR5c',
#   'statistics': {'viewCount': '466',
#    'likeCount': '9',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'a69KI_Tfko3jJcHxDm0L_ZuwKLw',
#   'id': 'vkqwsS3L13o',
#   'statistics': {'viewCount': '878',
#    'likeCount': '7',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': 'lxfLHDk6An1sloN58Auu4CXNA0M',
#   'id': 'HfAX9p8dNCY',
#   'statistics': {'viewCount': '383',
#    'likeCount': '8',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': 'Y3J6Sr6xAgSoaZDYTKTa71kX3rA',
#   'id': 'qSwdeqeHmRY',
#   'statistics': {'viewCount': '406',
#    'likeCount': '7',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': 'Op_iI34P3CrFqqNUogDZzGp2hZA',
#   'id': '3eAMvnIxQd0',
#   'statistics': {'viewCount': '407',
#    'likeCount': '11',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'c-Ua2y_vGzM1n1ZSCkzADHOfqTk',
#   'id': '3YrnVx8WLVQ',
#   'statistics': {'viewCount': '246',
#    'likeCount': '8',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '4'}},
#  {'kind': 'youtube#video',
#   'etag': 'MzUkANJUEM8P8bEIQjyYvEMvM1g',
#   'id': 'b8IpJT05uBo',
#   'statistics': {'viewCount': '302',
#    'likeCount': '11',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': 'TtIEZ-Fc6HUn2G5O3MTm-qXlpCI',
#   'id': 'WyzRRyKeea4',
#   'statistics': {'viewCount': '437',
#    'likeCount': '10',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '3'}},
#  {'kind': 'youtube#video',
#   'etag': 'SKbnDGMx8WAypjX99_PDIQRQuCg',
#   'id': 'Wa0e6R3sZWc',
#   'statistics': {'viewCount': '445',
#    'likeCount': '15',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'mIXB80Au3KeYntDnlFtlEK_vZZ4',
#   'id': 'j5EvjSLeRqg',
#   'statistics': {'viewCount': '644',
#    'likeCount': '13',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'RC8OjK6_xanNYGXj3HgNuIyGBNw',
#   'id': 'RgfOjrjhCMY',
#   'statistics': {'viewCount': '2467',
#    'likeCount': '48',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '10'}},
#  {'kind': 'youtube#video',
#   'etag': 'lTaI7HiePELNBVYQB9R1zfDW2gM',
#   'id': 'yAdGRuEarVw',
#   'statistics': {'viewCount': '855',
#    'likeCount': '26',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '7'}},
#  {'kind': 'youtube#video',
#   'etag': 'iDK0cX5hUggvIqQq_G-f8zvlceM',
#   'id': '-zJ1x2QHTKE',
#   'statistics': {'viewCount': '463',
#    'likeCount': '14',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'JGIy8meXUq7vafeZ1kzCS-Tcz70',
#   'id': 'gZEwmdgEMqE',
#   'statistics': {'viewCount': '458',
#    'likeCount': '14',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'dAcul9rLYAFJBJpSialOZ2NN8A4',
#   'id': 'KptmT3gQn3g',
#   'statistics': {'viewCount': '689',
#    'likeCount': '18',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': 'j5w3AlcRTZ8hmGMBLvbofHeycC4',
#   'id': 'v5u5zSYKhFs',
#   'statistics': {'viewCount': '756',
#    'likeCount': '23',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '1'}},
#  {'kind': 'youtube#video',
#   'etag': 'kwij6ktTV89BgSsZcAkYV1tgG9k',
#   'id': 'tmMqdrEzVRI',
#   'statistics': {'viewCount': '979',
#    'likeCount': '30',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '5'}},
#  {'kind': 'youtube#video',
#   'etag': 'eYKX0mVHl1pDmOAPBKBAgueXWyo',
#   'id': 'G7-Y0rhPPsw',
#   'statistics': {'viewCount': '139',
#    'likeCount': '9',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '4'}},
#  {'kind': 'youtube#video',
#   'etag': 'lt_BMFM48Jt97faVtv4V2kiGDkg',
#   'id': 'Kj8v9mYS0Ik',
#   'statistics': {'viewCount': '1274',
#    'likeCount': '54',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '5'}},
#  {'kind': 'youtube#video',
#   'etag': 'X-0Zg8WK9jN_kLhqMmi6xOr4LO4',
#   'id': 'zyo1PLw4hrE',
#   'statistics': {'viewCount': '970',
#    'likeCount': '33',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'zoREdjsAWZw6XmfvmH9gv-2GLeA',
#   'id': 'RH_lRGb-qds',
#   'statistics': {'viewCount': '625',
#    'likeCount': '21',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '4'}},
#  {'kind': 'youtube#video',
#   'etag': 'wJRg7Nmc_gZaz1mFcxf-pMKXwy4',
#   'id': 'Yr_PTfYElw8',
#   'statistics': {'viewCount': '575',
#    'likeCount': '19',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'mLI7ZQeOyYLLVSgoHHCtkb4L88c',
#   'id': 'DkO3g0ITyuc',
#   'statistics': {'viewCount': '571',
#    'likeCount': '25',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '10'}},
#  {'kind': 'youtube#video',
#   'etag': 'VmW324d9xLByFzFc_QDVoeexG_4',
#   'id': '1psWpWml_VE',
#   'statistics': {'viewCount': '426',
#    'likeCount': '29',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'gnJHkEpeyAkjU8-tMifs8vM31KM',
#   'id': 'Y4d7_0Tt0U0',
#   'statistics': {'viewCount': '3484',
#    'likeCount': '24',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '5'}},
#  {'kind': 'youtube#video',
#   'etag': 'zbdi2Wqj433_qpdntluzfMP8cxc',
#   'id': 'oOJr7XTj-Zw',
#   'statistics': {'viewCount': '489',
#    'likeCount': '16',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '10'}},
#  {'kind': 'youtube#video',
#   'etag': 'PYiiVv_eOk_CJQIoJjkqi3-qbEM',
#   'id': 'rlKl2q3Vy90',
#   'statistics': {'viewCount': '749',
#    'likeCount': '31',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '4'}},
#  {'kind': 'youtube#video',
#   'etag': 't86OQJfx7DGChPgkTYmnF7vm04I',
#   'id': 'gITfjV_Tdns',
#   'statistics': {'viewCount': '572',
#    'likeCount': '21',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '2'}},
#  {'kind': 'youtube#video',
#   'etag': 'OIfP_QWeLcKgMKTAFwkpAhUEGfM',
#   'id': 'CZzFbWAljp8',
#   'statistics': {'viewCount': '3410',
#    'likeCount': '44',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '10'}},
#  {'kind': 'youtube#video',
#   'etag': 'oB7Xh2yhKRzzalolqNiW1GzjzU0',
#   'id': 'IIzOQhf5AKo',
#   'statistics': {'viewCount': '1446',
#    'likeCount': '46',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '4'}},
#  {'kind': 'youtube#video',
#   'etag': 'X6j83iAhIysCwZPf6KImlpbmdDY',
#   'id': 'yGYMZIQQJTY',
#   'statistics': {'viewCount': '1034',
#    'likeCount': '37',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '5'}},
#  {'kind': 'youtube#video',
#   'etag': 'bp5DwMQO-MPT8i4cJTZCM2_mNPc',
#   'id': 'z4aaSVh5r_8',
#   'statistics': {'viewCount': '807',
#    'likeCount': '23',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '6'}},
#  {'kind': 'youtube#video',
#   'etag': 'OWiBtlz4cwtXwWensWSsyDqu__k',
#   'id': 'CoZbtZJg13A',
#   'statistics': {'viewCount': '1537',
#    'likeCount': '41',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '4'}},
#  {'kind': 'youtube#video',
#   'etag': 'JS5cN_Y17Gm8nQBSlSdaM--PKC4',
#   'id': 'wd3ZTyjknOo',
#   'statistics': {'viewCount': '392',
#    'likeCount': '5',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'oPNkxwlKNs2rWUSqHw3dtiUtnVo',
#   'id': 'qbZOytnC8eI',
#   'statistics': {'viewCount': '524',
#    'likeCount': '8',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'xnwEBeQwq-Q_iY2D8nPvjjbUitg',
#   'id': 'l3FfnXFcprU',
#   'statistics': {'viewCount': '333',
#    'likeCount': '10',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'G-gz6LtUh_ChkSGjpG4xKl8cDjk',
#   'id': 'vbs8_FlU63w',
#   'statistics': {'viewCount': '176',
#    'likeCount': '7',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'G3vkZSvvvDG2Lf9ChzJ79Q85aXs',
#   'id': 'B7aULKpPFWg',
#   'statistics': {'viewCount': '269',
#    'likeCount': '9',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'gmL4wmgS5CHi0ADk8wFEjwlAPu0',
#   'id': 'RzdBslEwsig',
#   'statistics': {'viewCount': '530',
#    'likeCount': '16',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '10'}},
#  {'kind': 'youtube#video',
#   'etag': 'KS2chpjaLE19j0VJKljV6weRmbI',
#   'id': 'LQ2hbNFOs_Q',
#   'statistics': {'viewCount': '6645',
#    'likeCount': '50',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '18'}},
#  {'kind': 'youtube#video',
#   'etag': 'C_NgKL8ML0zUEbS5izsXFiORbUo',
#   'id': 'dzPmX6jiuBs',
#   'statistics': {'viewCount': '202',
#    'likeCount': '7',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'wTqa_u3iev15AHNHRi2mqprWkzE',
#   'id': 'feJZ5gJKF0I',
#   'statistics': {'viewCount': '331',
#    'likeCount': '5',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': '_2z8AdR4MGfTzUgsWJvp8RelKHI',
#   'id': '1QAHGaw14P0',
#   'statistics': {'viewCount': '135',
#    'likeCount': '6',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'FXMdbZOMxvhkHy50r8jaaODyhFY',
#   'id': 'L1v9LcUyVGc',
#   'statistics': {'viewCount': '272',
#    'likeCount': '9',
#    'dislikeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '0'}}]
